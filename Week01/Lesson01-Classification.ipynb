# %% [markdown]
# <div class="alert alert-success">
#     <h1 align="center">Lesson 01: Image Classification (Cats vs Dogs)</h1>
#     <h3 align="center"><a href="http://www.snrazavi.ir">Seyed Naser RAZAVI</a></h3>
# </div>

# %% [markdown]
# <h6 align='center'>Kaggle competition: [Dogs vs. Cats](https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition)</h6>

# %% [markdown]
# <img src='imgs/catsanddogs.png' width='90%'/>

# %% [markdown]
# ## Objectives

# %% [markdown]
# - Image classification
# - Four key components of any ML system (in PyTorch):
#  - Data (Images)
#  - Model (CNN)
#  - Loss (Cross Entropy)
#  - Optimization (SGD, Adam, ..)
# - Convolutional Neural Networks (CNNs)
# - Overfit
# - Data augmentation
# - Transfer learning

# %% [markdown]
# ## Image Classification

# %% [markdown]
# <img src='imgs/Image_tasks.jpg' width='80%'/>

# %% [markdown]
# ## Libraries

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import math
import time
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from PIL import Image
from sklearn.metrics import confusion_matrix

import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
import torchvision.datasets as datasets
import torchvision.models as models
import torchvision.transforms as transforms

# Our libraries
from train import train_model
from model_utils import *
from predict_utils import *
from vis_utils import *

# some initial setup
np.set_printoptions(precision=2)
use_gpu = torch.cuda.is_available()
np.random.seed(1234)

# %%
use_gpu
# Out:
# True

# %% [markdown]
# ## Data

# %% [markdown]
# - train: learning the **parameters** of the model.
# - valid: learning **hyper-parameters**.
# - test
# - development

# %%
DATA_DIR = '/media/razavi/DATA/datasets/catsvsdogs/dev/'
sz = 224
batch_size = 16

# %%
os.listdir(DATA_DIR)
# Out:
# ['train', 'val', 'valid']

# %%
trn_dir = f'{DATA_DIR}train'
val_dir = f'{DATA_DIR}valid'

# %%
os.listdir(trn_dir)
# Out:
# ['cat', 'dog']

# %%
trn_fnames = glob.glob(f'{trn_dir}/*/*.jpg')
trn_fnames[:5]
# Out:
# ['/media/razavi/DATA/datasets/catsvsdogs/dev/train/cat/cat.420.jpg',
#  '/media/razavi/DATA/datasets/catsvsdogs/dev/train/cat/cat.1.jpg',
#  '/media/razavi/DATA/datasets/catsvsdogs/dev/train/cat/cat.10.jpg',
#  '/media/razavi/DATA/datasets/catsvsdogs/dev/train/cat/cat.100.jpg',
#  '/media/razavi/DATA/datasets/catsvsdogs/dev/train/cat/cat.101.jpg']

# %%
img = plt.imread(trn_fnames[3])
plt.imshow(img);

# %% [markdown]
# ### Datasets and Dataloaders in PyTorch

# %% [markdown]
# - <h6>Dataset</h6>A set of images.
# - <h6>Dataloader</h6>Loads data from dataset behind the scene using concurrent threads.

# %%
train_ds = datasets.ImageFolder(trn_dir)

# %%
train_ds.classes
# Out:
# ['cat', 'dog']

# %%
train_ds.class_to_idx
# Out:
# {'cat': 0, 'dog': 1}

# %%
train_ds.root
# Out:
# '/media/razavi/DATA/datasets/catsvsdogs/dev/train'

# %%
# train_ds.imgs

# %%
# list(zip(*train_ds.imgs))

# %%
type(train_ds.transform)
# Out:
# NoneType

# %% [markdown]
# ### Transformations

# %% [markdown]
# Dataloader object uses these tranformations when loading data.

# %%
tfms = transforms.Compose([
    transforms.Resize((sz, sz)),  # PIL Image
    transforms.ToTensor(),        # Tensor
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_ds = datasets.ImageFolder(trn_dir, transform=tfms)
valid_ds = datasets.ImageFolder(val_dir, transform=tfms)

# %%
len(train_ds), len(valid_ds)
# Out:
# (1600, 400)

# %% [markdown]
# #### Dataloaders

# %%
train_dl = torch.utils.data.DataLoader(train_ds, 
                                       batch_size=batch_size, 
                                       shuffle=True, 
                                       num_workers=8)

valid_dl = torch.utils.data.DataLoader(valid_ds, 
                                       batch_size=batch_size, 
                                       shuffle=False, 
                                       num_workers=8)

# %%
inputs, targets = next(iter(train_dl))
out = torchvision.utils.make_grid(inputs, padding=3)
plt.figure(figsize=(16, 12))
imshow(out, title='Random images from training data')

# %%
# ??imshow

# %% [markdown]
# ## Model: CNN

# %% [markdown]
# <img src='imgs/DogAndCats-CNN.jpg' width='100%'/>

# %%
class SimpleCNN(nn.Module):
    
    def __init__(self):
        super(SimpleCNN, self).__init__()
        
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=5, padding=2),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.conv2 = nn.Sequential(
            nn.Conv2d(16, 32, kernel_size=5, padding=2),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.fc = nn.Linear(56 * 56 * 32, 2)
        
    def forward(self, x):
        out = self.conv1(x)
        out = self.conv2(out)            # (bs, C, H,  W)
        out = out.view(out.size(0), -1)  # (bs, C * H, W)
        out = self.fc(out)
        return out

# %% [markdown]
# Now, it's time to create the model and to put it on the GPU.

# %%
model = SimpleCNN()

# transfer model to GPU, if gpu is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = model.to(device)

# %%
model
# Out:
# SimpleCNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc): Linear(in_features=100352, out_features=2, bias=True)
# )

# %% [markdown]
# ## Loss function and optimizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.002, momentum=0.9)

# %% [markdown]
# ## Train

# %%
num_epochs = 10
losses = []

for epoch in range(num_epochs):
    for i, (inputs, targets) in enumerate(train_dl):
        inputs = inputs.to(device)
        targets = targets.to(device)
        
        # forwad pass
        outputs = model(inputs)
        
        # loss
        loss = criterion(outputs, targets)
        losses.append(loss.item())

        # backward pass
        optimizer.zero_grad()
        loss.backward()
        
        # update parameters
        optimizer.step()
        
        # report
        if (i + 1) % 50 == 0:
            print('Epoch [%2d/%2d], Step [%3d/%3d], Loss: %.4f'
                  % (epoch + 1, num_epochs, i + 1, len(train_ds) // batch_size, loss.item()))
# Out:
# /home/razavi/Documents/mygithub/DeepLearning/Deep_Learning_in_Python_2018/venv/lib/python3.6/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch [ 1/10], Step [ 50/100], Loss: 1.9584
# Epoch [ 1/10], Step [100/100], Loss: 0.6362
# Epoch [ 2/10], Step [ 50/100], Loss: 0.7224
# Epoch [ 2/10], Step [100/100], Loss: 0.6368
# Epoch [ 3/10], Step [ 50/100], Loss: 0.5769
# Epoch [ 3/10], Step [100/100], Loss: 0.5366
# Epoch [ 4/10], Step [ 50/100], Loss: 0.6253
# Epoch [ 4/10], Step [100/100], Loss: 0.7052
# Epoch [ 5/10], Step [ 50/100], Loss: 0.4905
# Epoch [ 5/10], Step [100/100], Loss: 0.6012
# Epoch [ 6/10], Step [ 50/100], Loss: 0.6368
# Epoch [ 6/10], Step [100/100], Loss: 0.6313
# Epoch [ 7/10], Step [ 50/100], Loss: 0.6263
# Epoch [ 7/10], Step [100/100], Loss: 0.7179
# Epoch [ 8/10], Step [ 50/100], Loss: 0.4246
# Epoch [ 8/10], Step [100/100], Loss: 0.4011
# Epoch [ 9/10], Step [ 50/100], Loss: 0.3184
# Epoch [ 9/10], Step [100/100], Loss: 0.2640
# Epoch [10/10], Step [ 50/100], Loss: 0.4186
# Epoch [10/10], Step [100/100], Loss: 0.5613

# %%
plt.figure(figsize=(12, 4))
plt.plot(losses)
plt.xlabel('Iteration')
plt.ylabel('loss')
plt.title('Cross Entropy Loss');

# %% [markdown]
# ### Analyze results

# %% [markdown]
# #### Accuracy on validation data

# %%
def evaluate_model(model, dataloader, device):
    model.eval()  # for batch normalization layers
    corrects = 0
    
    with torch.no_grad():
        for inputs, targets in dataloader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            corrects += (preds == targets.data).sum()
    
    print('accuracy: {:.2f}'.format(100. * corrects / len(dataloader.dataset)))

# %%
evaluate_model(model, valid_dl, device)
# Out:
# accuracy: 64.00

# %%
evaluate_model(model, train_dl, device)
# Out:
# accuracy: 90.44

# %%
visualize_model(model, train_dl, device)

# %%
visualize_model(model, valid_dl, device)

# %%
plot_errors(model, valid_dl, device)
# Out:
# 100%|██████████| 25/25 [00:01<00:00, 14.38it/s]
# 50 images out of 400 were misclassified.

# %% [markdown]
# #### Confusion matrix

# %%
y_pred, y_true = predict_class(model, valid_dl, device)
cm = confusion_matrix(y_true, y_pred)
plot_confusion_matrix(cm, train_ds.classes, normalize=True, figsize=(4, 4))
# Out:
# 100%|██████████| 25/25 [00:00<00:00, 26.12it/s]
# [[0.6  0.4 ]
#  [0.32 0.68]]

# %% [markdown]
# ## Overfit

# %% [markdown]
# <div class="alert alert-success">
#     <strong>What is OVERFIT? </strong>
#     <ul>
#         <li>The most important concept in ML!</li>
#         <li>Simply, it means that your model is too complex for your problem.</li>
#     </ul>
# </div>

# %% [markdown]
# <h6>What we can do about it?</h6>

# %% [markdown]
# - Regularization
# - Dropout
# - Data Augmentation
# - Transfer Learning

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# <img src='imgs/Augmentation.jpg' width='90%'/>

# %% [markdown]
# <h6>Possible Transformations:</h6>
# - Scaling
# - Rotation
# - Translation
# - Flip horizontaly
# - Random Crop
# - Color jitter
# - many more!

# %% [markdown]
# <img src='imgs/Augmentation-Examples.jpg' width='75%'/>

# %%
# Data augmentation and normalization for training
train_transforms = transforms.Compose([
    transforms.Resize((sz, sz)),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(0.1, 0.1, 0.1, 0.01),
    transforms.RandomRotation(20),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Just normalization for validation
valid_transforms = transforms.Compose([
    transforms.Resize((sz, sz)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_ds = datasets.ImageFolder(f'{DATA_DIR}train', train_transforms)
valid_ds = datasets.ImageFolder(f'{DATA_DIR}valid', valid_transforms)

train_dl = torch.utils.data.DataLoader(train_ds, batch_size=batch_size, shuffle=True)
valid_dl = torch.utils.data.DataLoader(valid_ds, batch_size=batch_size, shuffle=True)

train_ds_sz = len(train_ds)
valid_ds_sz = len(valid_ds)

print('Train size: {}\nValid size: {} ({:.2f})'.format(train_ds_sz, valid_ds_sz, valid_ds_sz/(train_ds_sz + valid_ds_sz)))

class_names = train_ds.classes
# Out:
# Train size: 1600
# Valid size: 400 (0.20)

# %%
inputs, targets = next(iter(train_dl))     # Get a batch of training data
out = torchvision.utils.make_grid(inputs)  # Make a grid from batch
plt.figure(figsize=(16., 12.))
imshow(out, title='Augmented Images');

# %% [markdown]
# #### Look at the sizes of the images

# %%
fnames = glob.glob(f'{trn_dir}/*/*.jpg')
sizes = [Image.open(f).size for f in fnames]

hs, ws = list(zip(*sizes))

plt.figure(figsize=(12., 4.))
plt.hist(hs)
plt.hist(ws);

# %%
# create model
model = SimpleCNN()
model = model.to(device)
    
# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.002, momentum=0.9)

# train
model = train_model(model, train_dl, valid_dl, criterion, optimizer, device, num_epochs=5)
# Out:
# Epoch 1/5
# ----------
#   train Loss: 6.88310 Acc: 0.51187
#   valid Loss: 0.69515 Acc: 0.53750
#
# Epoch 2/5
# ----------
#   train Loss: 0.68167 Acc: 0.56625
#   valid Loss: 0.72463 Acc: 0.54750
#
# Epoch 3/5
# ----------
#   train Loss: 0.66915 Acc: 0.59187
#   valid Loss: 0.69541 Acc: 0.58000
#
# Epoch 4/5
# ----------
#   train Loss: 0.64016 Acc: 0.64000
#   valid Loss: 0.70738 Acc: 0.56500
#
# Epoch 5/5
# ----------
#   train Loss: 0.65184 Acc: 0.60375
#   valid Loss: 0.68636 Acc: 0.57250
#
# Training complete in 1m 53s
# Best val Acc: 0.5800

# %% [markdown]
# ## Transfer Learning

# %% [markdown]
# - Use a CNN already trained on different data (e.g., [ImageNet](http://www.image-net.org/))
# - Just Train the classifier weights (Last Layer)

# %% [markdown]
# <img src='imgs/transfer-learning.jpg' width='80%'/>

# %%
# load pre-trained ResNet18
model = load_pretrained_resnet50(model_path=None, num_classes=2)
model = model.to(device)

# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.002, momentum=0.9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.9)

# %%
model = train_model(model, train_dl, valid_dl, criterion, optimizer, device, scheduler, num_epochs=2)
# Out:
# Epoch 1/2
# ----------
#   train Loss: 0.16523 Acc: 0.92750
#   valid Loss: 0.04608 Acc: 0.98000
#
# Epoch 2/2
# ----------
#   train Loss: 0.05373 Acc: 0.98438
#   valid Loss: 0.03638 Acc: 0.99000
#
# Training complete in 1m 39s
# Best val Acc: 0.9900

# %%
evaluate_model(model, valid_dl, device)
# Out:
# accuracy: 99.00

# %%
visualize_model(model, valid_dl, device, num_images=6)

# %%
plot_errors(model, valid_dl, device)
# Out:
# 100%|██████████| 25/25 [00:04<00:00,  6.06it/s]
# 4 images out of 400 were misclassified.

# %% [markdown]
# ## PROGRAMMING ASSIGNMENT 1

# %% [markdown]
# <div class="alert alert-success">
#     <strong>[Plant Seeldlings Competition](https://www.kaggle.com/c/plant-seedlings-classification)</strong>
#     <img src='imgs/PlantSeedling.png'/>
#     <ul>
#         <li><strong>Objective:</strong> getting a rank among top 50% in LB.</li>
#         <li><strong>Ideas:</strong> different augmentations, different architectures, etc.</li>
#         <li><strong>Important:</strong> share your ideas and progress on Piazz.</li>
#     </ul>
# </div>
